# %%
# !pip install rdkit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 23.5 MB/s eta 0:00:00
# ...

# %%
# !pip install lightgbm optuna
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 19.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python "/content/drp_baseline_fast.py"" \
  --data "/content/drive/MyDrive/drugresponse/data/processed/merged.parquet" \
  --out "/content/drive/MyDrive/drugresponse/results/baseline_lgbm_fast" \
  --group_by drug \
  --use_tissue
  --trials 50
# Out:
# Loaded data: (562789, 519)
# Expr shape: (562789, 512) Drug featurization shape: (562789, 262)
# ^C
