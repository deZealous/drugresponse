# %%
# !pip install optuna
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 28.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/drugresponse/scripts/tune_mlp_chemberta.py \
    --data /content/drive/MyDrive/drugresponse/data/processed/merged.parquet \
    --chemberta_npz /content/drive/MyDrive/drugresponse/data/processed/chemberta_drug_feats.npz \
    --splits_dir /content/drive/MyDrive/drugresponse/data/processed/splits_drug \
    --out /content/drive/MyDrive/drugresponse/results/mlp_chemberta_tuned \
    --use_tissue \
    --trials 25
# Out:
# Using device: cuda
# Loaded: (562789, 519)
# Expr dim: 512
# Drug dim: 768
# Tissue dim: 57
# Using splits: /content/drive/MyDrive/drugresponse/data/processed/splits_drug
# Train/Val/Test sizes: 395596 54216 112977
# [I 2025-12-05 10:38:36,668] A new study created in memory with name: no-name-d996ef4a-7463-429d-ba9c-517846a430a0
# [I 2025-12-05 10:40:41,592] Trial 0 finished with value: 2.0947465896606445 and parameters: {'n_layers': 2, 'hidden_0': 180, 'hidden_1': 505, 'dropout': 0.3109040019106423, 'lr': 0.0007396384757037711, 'weight_decay': 2.1202689575410238e-08, 'batch_size': 1024}. Best is trial 0 with value: 2.0947465896606445.
# [I 2025-12-05 10:41:16,565] Trial 1 finished with value: 2.335387706756592 and parameters: {'n_layers': 1, 'hidden_0': 1007, 'dropout': 0.06789437236301987, 'lr': 0.0001584645008488399, 'weight_decay': 5.38767913839487e-06, 'batch_size': 512}. Best is trial 0 with value: 2.0947465896606445.
# ...
