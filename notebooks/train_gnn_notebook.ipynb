# %%
# !pip install rdkit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 76.5 MB/s eta 0:00:00
# ...

# %%
# !pip install -q torch_geometric
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 36.1 MB/s eta 0:00:00

# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/drugresponse/scripts/train_gnn.py \
    --data /content/drive/MyDrive/drugresponse/data/processed/merged.parquet \
    --graphs_pt /content/drive/MyDrive/drugresponse/data/processed/mol_graphs.pt \
    --splits_dir /content/drive/MyDrive/drugresponse/data/processed/splits_drug \
    --out /content/drive/MyDrive/drugresponse/results/gnn_baseline \
    --use_tissue
# Out:
# Using device: cuda
# Loaded: (562789, 519)
# Tissue one-hot shape: (562789, 57)
# Tissue one-hot sample (first row): (57,) [0. 0. 0. 0. 0.]
# Using splits from: /content/drive/MyDrive/drugresponse/data/processed/splits_drug
# After subset - train tissue shape: (395596, 57)
# After subset - train tissue sample: (57,)
# Creating dataset with: drug_idx=(395596,), expr=(395596, 512), tissue=(395596, 57), y=(395596,)
# Dataset initialized with tissue shape: (395596, 57)
# Dataset tissue[0] shape: (57,)
# Dataset initialized with tissue shape: (54216, 57)
# Dataset tissue[0] shape: (57,)
# Dataset initialized with tissue shape: (112977, 57)
# Dataset tissue[0] shape: (57,)
# Input dimensions: expr=512, gnn_out=128, tissue=57, total=697
# Collate - tissue[0] shape: (57,), stacked shape: (256, 57)
# Debug shapes - expr: torch.Size([256, 512]), mol_emb: torch.Size([256, 128]), tissue: torch.Size([256, 57])
# Epoch 001 | train_rmse=2.3967 val_rmse=2.3391 val_spearman=0.4235
# ...
