# %%
# !pip install -q transformers accelerate

# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/drugresponse/scripts/make_chemberta_features.py \
    --data /content/drive/MyDrive/drugresponse/data/processed/merged.parquet \
    --out_npz /content/drive/MyDrive/drugresponse/data/processed/chemberta_drug_feats.npz
# Out:
# Using device: cuda
# Loaded merged data: (562789, 519)
# Unique drugs: 621
# tokenizer_config.json: 100% 166/166 [00:00<00:00, 1.51MB/s]
# config.json: 100% 501/501 [00:00<00:00, 4.24MB/s]
# vocab.json: 9.43kB [00:00, 36.6MB/s]
# merges.txt: 3.21kB [00:00, 20.9MB/s]
# special_tokens_map.json: 100% 150/150 [00:00<00:00, 1.74MB/s]
# 2025-12-04 15:23:19.914115: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-04 15:23:19.931530: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...
