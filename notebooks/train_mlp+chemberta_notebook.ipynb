# %%
# !pip install rdkit
# Out:
# Collecting rdkit
#   Downloading rdkit-2025.9.3-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit) (11.3.0)
# Downloading rdkit-2025.9.3-cp312-cp312-manylinux_2_28_x86_64.whl (36.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 29.3 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2025.9.3

# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/drugresponse/scripts/train_mlp_use_chemBERTa.py \
    --data /content/drive/MyDrive/drugresponse/data/processed/merged.parquet \
    --splits_dir /content/drive/MyDrive/drugresponse/data/processed/splits_drug \
    --chemberta_npz /content/drive/MyDrive/drugresponse/data/processed/chemberta_drug_feats.npz \
    --out /content/drive/MyDrive/drugresponse/results/mlp_chemberta \
    --use_tissue \
    --hidden 1024,512 \
    --batch_size 1024 \
    --epochs 100 \
    --patience 10
# Out:
# Using device: cuda
# Loaded data: (562789, 519)
# Using ChemBERTa drug features from /content/drive/MyDrive/drugresponse/data/processed/chemberta_drug_feats.npz
# Expr shape: (562789, 512) Drug features shape: (562789, 768)
# Using tissue; Xt shape: (562789, 57)
# Using fixed splits from: /content/drive/MyDrive/drugresponse/data/processed/splits_drug
#
# Validation metrics: {'rmse': 2.1146504878997803, 'mae': 1.6370879411697388, 'spearman': 0.5206902511188867}
# Test metrics      : {'rmse': 2.5876078605651855, 'mae': 1.9922457933425903, 'spearman': 0.4069136526830091}
