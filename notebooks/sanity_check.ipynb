# %%
import pandas as pd
df = pd.read_parquet("data/processed/merged.parquet")
print(df.shape, df.columns[:10])
print("unique cells:", df.cell_id.nunique(), "unique drugs:", df.drug_id.nunique())
print("SMILES coverage:", (df.smiles!="").mean())
print("tissue coverage:", (df.tissue!="unknown").mean())
# Out:
# (562789, 519) Index(['cell_id', 'drug_id', 'drug_name', 'smiles', 'tissue', 'dataset',
#        'ln_ic50', 'PC1', 'PC2', 'PC3'],
#       dtype='object')
# unique cells: 947 unique drugs: 621
# SMILES coverage: 0.8911936800470514
# tissue coverage: 1.0

# %%
import pandas as pd
df = pd.read_parquet("C:/Users/hrm01/drug_response_prediction/data/processed/merged.parquet")

print(df.shape)
print(df.head())

print("unique cells:", df.cell_id.nunique())
print("unique drugs:", df.drug_id.nunique())
print("tissues:", df.tissue.value_counts().head(20))

print("ln_ic50 stats:\n", df.ln_ic50.describe())
# Out:
# (562789, 519)
#   cell_id  drug_id    drug_name  \
# 0  683667      133  Doxorubicin
# 1  683667      134    Etoposide
# 2  683667      135  Gemcitabine
# 3  683667      136  Mitomycin-C
# 4  683667      140  Vinorelbine
#
#                                               smiles  \
# 0  COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)...
# 1  COc1cc([C@@H]2c3cc4c(cc3[C@@H](O[C@@H]3O[C@@H]...
# 2    Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)C2(F)F)c(=O)n1
# 3  CO[C@@]12[C@H](COC(N)=O)C3=C(C(=O)C(C)=C(N)C3=...
# 4  CCC1=C[C@@H]2CN(C1)Cc1c([nH]c3ccccc13)[C@@](C(...
#
#                              tissue dataset   ln_ic50        PC1        PC2  \
# 0  nervous_system / medulloblastoma   GDSC1 -1.044427  13.976314 -23.808541
# 1  nervous_system / medulloblastoma   GDSC1  3.130794  13.976314 -23.808541
# 2  nervous_system / medulloblastoma   GDSC1 -0.408147  13.976314 -23.808541
# 3  nervous_system / medulloblastoma   GDSC1  1.561341  13.976314 -23.808541
# 4  nervous_system / medulloblastoma   GDSC1 -4.224251  13.976314 -23.808541
#
#         PC3  ...     PC503     PC504     PC505     PC506     PC507     PC508  \
# 0 -6.438696  ...  0.479473 -0.014741 -0.530388  0.549369 -1.664745 -0.892558
# 1 -6.438696  ...  0.479473 -0.014741 -0.530388  0.549369 -1.664745 -0.892558
# 2 -6.438696  ...  0.479473 -0.014741 -0.530388  0.549369 -1.664745 -0.892558
# 3 -6.438696  ...  0.479473 -0.014741 -0.530388  0.549369 -1.664745 -0.892558
# 4 -6.438696  ...  0.479473 -0.014741 -0.530388  0.549369 -1.664745 -0.892558
#
#       PC509     PC510     PC511     PC512
# 0  1.625395  0.419378 -1.013034 -1.634409
# 1  1.625395  0.419378 -1.013034 -1.634409
# 2  1.625395  0.419378 -1.013034 -1.634409
# 3  1.625395  0.419378 -1.013034 -1.634409
# 4  1.625395  0.419378 -1.013034 -1.634409
#
# [5 rows x 519 columns]
# unique cells: 947
# unique drugs: 621
#   cell_id  drug_id    drug_name  \
# 0  683667      133  Doxorubicin
# 1  683667      134    Etoposide
# 2  683667      135  Gemcitabine
# 3  683667      136  Mitomycin-C
# 4  683667      140  Vinorelbine
#
#                                               smiles  \
# 0  COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)...
# 1  COc1cc([C@@H]2c3cc4c(cc3[C@@H](O[C@@H]3O[C@@H]...
# 2    Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)C2(F)F)c(=O)n1
# 3  CO[C@@]12[C@H](COC(N)=O)C3=C(C(=O)C(C)=C(N)C3=...
# 4  CCC1=C[C@@H]2CN(C1)Cc1c([nH]c3ccccc13)[C@@](C(...
#
#                              tissue dataset   ln_ic50        PC1        PC2  \
# 0  nervous_system / medulloblastoma   GDSC1 -1.044427  13.976314 -23.808541
# 1  nervous_system / medulloblastoma   GDSC1  3.130794  13.976314 -23.808541
# 2  nervous_system / medulloblastoma   GDSC1 -0.408147  13.976314 -23.808541
# 3  nervous_system / medulloblastoma   GDSC1  1.561341  13.976314 -23.808541
# 4  nervous_system / medulloblastoma   GDSC1 -4.224251  13.976314 -23.808541
#
#         PC3  ...     PC503     PC504     PC505     PC506     PC507     PC508  \
# 0 -6.438696  ...  0.479473 -0.014741 -0.530388  0.549369 -1.664745 -0.892558
# 1 -6.438696  ...  0.479473 -0.014741 -0.530388  0.549369 -1.664745 -0.892558
# 2 -6.438696  ...  0.479473 -0.014741 -0.530388  0.549369 -1.664745 -0.892558
# 3 -6.438696  ...  0.479473 -0.014741 -0.530388  0.549369 -1.664745 -0.892558
# 4 -6.438696  ...  0.479473 -0.014741 -0.530388  0.549369 -1.664745 -0.892558
#
#       PC509     PC510     PC511     PC512
# 0  1.625395  0.419378 -1.013034 -1.634409
# 1  1.625395  0.419378 -1.013034 -1.634409
# 2  1.625395  0.419378 -1.013034 -1.634409
# 3  1.625395  0.419378 -1.013034 -1.634409
# 4  1.625395  0.419378 -1.013034 -1.634409
#
# [5 rows x 519 columns]
# unique cells: 947
# unique drugs: 621
# tissues: tissue
# lung_NSCLC / lung_NSCLC_adenocarcinoma    38353
# lung_SCLC / lung_small_cell_carcinoma     32156
# skin / melanoma                           30587
# breast                                    30178
# nervous_system / glioma                   30096
# large_intestine                           27436
# aero_dig_tract / head and neck            24092
# urogenital_system / ovary                 23744
# aero_dig_tract / oesophagus               21262
# kidney                                    18532
# pancreas                                  18488
# lymphoma / B_cell_lymphoma                18447
# neuroblastoma                             17430
# digestive_system / stomach                15515
# leukemia / acute_myeloid_leukaemia        15218
# lung / mesothelioma                       12628
# bone / ewings_sarcoma                     12408
# urogenital_system / Bladder               11030
# digestive_system / liver                   9517
# thyroid                                    9052
# Name: count, dtype: int64
# ln_ic50 stats:
#  count    562789.000000
# mean          2.386286
# std           2.661361
# min          -5.989046
# 25%           1.018011
# 50%           2.790352
# 75%           4.277516
# max           8.431898
# Name: ln_ic50, dtype: float64
# tissues: tissue
# lung_NSCLC / lung_NSCLC_adenocarcinoma    38353
# lung_SCLC / lung_small_cell_carcinoma     32156
# skin / melanoma                           30587
# breast                                    30178
# nervous_system / glioma                   30096
# large_intestine                           27436
# aero_dig_tract / head and neck            24092
# urogenital_system / ovary                 23744
# aero_dig_tract / oesophagus               21262
# kidney                                    18532
# pancreas                                  18488
# lymphoma / B_cell_lymphoma                18447
# neuroblastoma                             17430
# digestive_system / stomach                15515
# leukemia / acute_myeloid_leukaemia        15218
# lung / mesothelioma                       12628
# bone / ewings_sarcoma                     12408
# urogenital_system / Bladder               11030
# digestive_system / liver                   9517
# thyroid                                    9052
# Name: count, dtype: int64
# ln_ic50 stats:
#  count    562789.000000
# mean          2.386286
# std           2.661361
# min          -5.989046
# 25%           1.018011
# 50%           2.790352
# 75%           4.277516
# max           8.431898
# Name: ln_ic50, dtype: float64
