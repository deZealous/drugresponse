# %%
# !pip install rdkit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 69.3 MB/s eta 0:00:00
# ...

# %%
# !pip install -q torch_geometric
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 32.4 MB/s eta 0:00:00

# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/drugresponse/scripts/make_mol_graphs.py \
    --data /content/drive/MyDrive/drugresponse/data/processed/merged.parquet \
    --out_pt /content/drive/MyDrive/drugresponse/data/processed/mol_graphs.pt
# Out:
# Loaded merged data: (562789, 519)
# Unique drugs: 621
# Building graphs: 100% 621/621 [00:00<00:00, 1438.65it/s]
# Saved graphs to: /content/drive/MyDrive/drugresponse/data/processed/mol_graphs.pt
